# %%
import os, sys

sys.path.append('./utilities/')
from loading_utilities import *

# Load all Pathfinder data
data = load_pathfinder_data()

# %%
data.keys()
# Out:
# ['armor', 'magicItems', 'weapons', 'traits', 'bestiary', 'feats', 'spells']

# %%
data['armor']
# Out:
#                                Armor      Cost Armor/Shield Bonus  \
# 0                      Armored kilt*     20 gp                  1
# 1                    Dancing scarves    150 gp           See text
# 2                           Haramaki      3 gp                  1
# 3                             Padded      5 gp                  1
# 4                      Quilted cloth    100 gp                  1
# 5                   Reinforced tunic      1 gp                  1
# 6            Silken ceremonial armor     30 gp                  1
# 7                   Lamellar cuirass     15 gp                  2
# 8                            Leather     10 gp                  2
# 9                     Rosewood armor     50 gp                  2
# 10               Hell Knight leather     30 gp                  3
# 11                        Hide shirt     20 gp                  3
# 12                        Leaf armor    500 gp                  3
# ...

# %%
data['armor'].loc[1]
# Out:
# Armor                          Dancing scarves
# Cost                                    150 gp
# Armor/Shield Bonus                    See text
# MaximumDexBonus                              —
# Armor Check Penalty                          0
# Arcane Spell Failure Chance                  —
# Speed-30                                30 ft.
# Speed-20                                20 ft.
# Weight1                                 8 lbs.
# Source                               PPZO94102
# Type                                     Light
# Name: 1, dtype: object

# %%
list( data['armor']['Cost'] )
# Out:
# [u'20 gp',
#  u'150 gp',
#  u'3 gp',
#  u'5 gp',
#  u'100 gp',
#  u'1 gp',
#  u'30 gp',
#  u'15 gp',
#  u'10 gp',
#  u'50 gp',
#  u'30 gp',
#  u'20 gp',
#  u'500 gp',
#  u'25 gp',
#  u'850 gp',
#  u'25 gp',
#  u'20 gp',
#  u'100 gp',
#  u'60 gp',
#  u'50 gp',
#  u'75 gp',
#  u'15 gp',
#  u'80 gp',
#  u'200 gp',
#  u'250 gp',
#  u'100 gp',
#  u'50 gp',
#  u'200 gp',
#  u'400 gp',
#  u'150 gp',
#  u'125 gp',
#  u'150 gp',
#  u'250 gp',
#  u'250 gp',
#  u'1,200 gp',
#  u'350 gp',
#  u'200 gp',
#  u'200 gp',
#  u'1000 gp',
#  u'2,100 gp',
#  u'600 gp',
#  u'850 gp',
#  u'850 gp',
#  u'500 gp',
#  u'1,700 gp',
#  u'1,500 gp',
#  u'1,500 gp',
#  u'2,000 gp',
#  u'1,800 gp',
#  u'5 gp',
#  u'12 gp',
#  u'30 gp',
#  u'40 gp',
#  u'9 gp',
#  u'59 gp',
#  u'3 gp',
#  u'53 gp',
#  u'20 gp',
#  u'7 gp',
#  u'30 gp',
#  u'50 gp',
#  u'37 gp',
#  u'50 gp']

# %%
data['armor'].keys()
# Out:
# Index([u'Armor', u'Cost', u'Armor/Shield Bonus', u'MaximumDexBonus',
#        u'Armor Check Penalty', u'Arcane Spell Failure Chance', u'Speed-30',
#        u'Speed-20', u'Weight1', u'Source', u'Type'],
#       dtype='object')

# %%
x
# Out:
#                                Armor      Cost Armor/Shield Bonus  \
# 0                      Armored kilt*     20 gp                  1
# 1                    Dancing scarves    150 gp           See text
# 2                           Haramaki      3 gp                  1
# 3                             Padded      5 gp                  1
# 4                      Quilted cloth    100 gp                  1
# 5                   Reinforced tunic      1 gp                  1
# 6            Silken ceremonial armor     30 gp                  1
# 7                   Lamellar cuirass     15 gp                  2
# 8                            Leather     10 gp                  2
# 9                     Rosewood armor     50 gp                  2
# 10               Hell Knight leather     30 gp                  3
# 11                        Hide shirt     20 gp                  3
# 12                        Leaf armor    500 gp                  3
# ...

# %%
x.keys()
# Out:
# Index([u'Armor', u'Cost', u'Armor/Shield Bonus', u'MaximumDexBonus',
#        u'Armor Check Penalty', u'Arcane Spell Failure Chance', u'Speed-30',
#        u'Speed-20', u'Weight1', u'Source', u'Type'],
#       dtype='object')
